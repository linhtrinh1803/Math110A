# %% [markdown]
# ### 1.

# %%
import numpy as np
import pandas as pd

# %%
fb = pd.read_csv('fb.csv').Price.tolist()
fb
# Out:
# ['$327.74 ',
#  '$340.89 ',
#  '$347.56 ',
#  '$342.96 ',
#  '$340.77 ',
#  '$338.69 ',
#  '$345.30 ',
#  '$341.01 ',
#  '$337.25 ',
#  '$341.06 ',
#  '$333.12 ',
#  '$338.03 ',
#  '$324.46 ',
#  '$310.60 ',
#  '$310.39 ',
#  '$306.84 ',
#  '$317.87 ',
#  '$322.81 ',
#  '$330.56 ',
#  '$329.82 ']

# %%
R = []
for i in range(19):
    Rn = (fb(float([i+1]) - fb[i])/(fb[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-41405c0ff490> in <module>
#       1 R = np.zeros(shape=(19,1))
#       2 for i in range(19):
# ----> 3     R[i] = (price_fb[i+1] - price_fb[i])/(price_fb[i])
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
log_fb = np.log(R+1) 
mu_d = sum(log_)/len(R)
log_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-633e97612758> in <module>
# ----> 1 log_fb = np.log(R+1)
#       2 mu_d = sum(log_)/len(R)
#       3 log_
#
# TypeError: can only concatenate list (not "int") to list

# %%
mu_hat = mu_d + 252
mu_hat
# Out:
# nan

# %%
a = (log_ - mu_d)**2
sigma_d = np.sqrt(sum(a/18))
sigma_d
# Out:
# nan

# %%
sigma_hat = np.sqrt(252) *sigma_d
sigma_hat
# Out:
# nan

# %%
goog = pd.read_csv('goog.csv').Price

# %% [markdown]
# ### 2.
